# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"D:\campusx_dsmp2\9. MLOps revisited\cars24_mlops_project\experiment\cars24_v2.xlsx")

# %%
df.sample(3)
# Out:
#      appointmentId  listingPrice        carName     make  model  \
# 4084    DLR1000516        671000  Hyundai Verna  Hyundai  Verna
# 6461   11395124766        670000   Maruti Swift   Maruti  Swift
# 6251   11363340778        360000  Hyundai Verna  Hyundai  Verna
#
#                     variant  year transmissionType   bodyType fuelType  ...  \
# 4084  FLUIDIC 1.6 CRDI S 4S  2015           Manual      Sedan   Diesel  ...
# 6461               ZXI PLUS  2020           Manual  Hatchback   Petrol  ...
# 6251       FLUIDIC 1.4 VTVT  2013           Manual      Sedan   Petrol  ...
#
#       InfotainmentSystem LeatherSeats ParkingAssist PushButtonStart  RearAc  \
# 4084                   0            0             0               0       0
# 6461                   1            0             1               1       0
# 6251                   0            0             0               0       0
#
#      SpecialRegNo  Sunroof/Moonroof TopModel  Tpms  VentilatedSeats
# ...

# %%
df.columns
# Out:
# Index(['appointmentId', 'listingPrice', 'carName', 'make', 'model', 'variant',
#        'year', 'transmissionType', 'bodyType', 'fuelType', 'ownership',
#        'registrationDate', 'cityRto', 'color', 'odometer', 'modelGroup',
#        'fitnessAge', 'features', 'cashDownPayment', 'emiStartingValue',
#        'emiEndingValue', 'roiMinDiscounted', 'roiMaxDiscounted',
#        'roiMinOriginal', 'roiMaxOriginal', 'emiOriginalStartingValue',
#        'emiOriginalEndingValue', 'tenure', 'displayText', 'notAvailableText',
#        'registeredCity', '360DegreeCamera', 'AlloyWheels',
#        'AppleCarplayAndroidAuto', 'Bluetooth', 'CruiseControl',
#        'GpsNavigation', 'InfotainmentSystem', 'LeatherSeats', 'ParkingAssist',
#        'PushButtonStart', 'RearAc', 'SpecialRegNo', 'Sunroof/Moonroof',
#        'TopModel', 'Tpms', 'VentilatedSeats'],
#       dtype='object')

# %% [markdown]
# ##### Label columns

# %%
# Get the list of numerical columns
numerical_columns = df.select_dtypes(include=['number']).columns.tolist()

# Get the list of categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()

# %% [markdown]
# #### Univariate Analysis on Numerical Columns
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### listingPrice
#
# 1. most of the cars listed on cars24 are under 5-6lakhs

# %%
df['listingPrice'].describe().apply(lambda x: f"{x:,.0f}")
# Out:
# count         7,391
# mean        695,376
# std         696,695
# min          36,000
# 25%         380,000
# 50%         559,000
# 75%         813,200
# max      25,000,000
# Name: listingPrice, dtype: object

# %%
df['listingPrice'].plot(kind='hist', bins=20, edgecolor='black'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()
# Out:
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\2923209250.py:1: UserWarning: FixedFormatter should only be used together with FixedLocator
#   df['listingPrice'].plot(kind='hist', bins=20, edgecolor='black'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()

# %%
df['listingPrice'].plot(kind='kde'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()
# Out:
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\1807776302.py:1: UserWarning: FixedFormatter should only be used together with FixedLocator
#   df['listingPrice'].plot(kind='kde'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()

# %% [markdown]
# ##### year
# 1. most of the cars listed on cars24 are manufactured in 2017 - 2025
# 2. maruti swift and alto being exceptionally old: 2005 and still being sold

# %%
df['year'].describe()
# Out:
# count    7391.000000
# mean     2018.189014
# std         3.547569
# min      2005.000000
# 25%      2016.000000
# 50%      2018.000000
# 75%      2021.000000
# max      2025.000000
# Name: year, dtype: float64

# %%
df['year'].plot(kind='hist', bins=20, edgecolor='black'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()
# Out:
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\3446791794.py:1: UserWarning: FixedFormatter should only be used together with FixedLocator
#   df['year'].plot(kind='hist', bins=20, edgecolor='black'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()

# %%
df['year'].plot(kind='kde'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()
# Out:
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\4031451388.py:1: UserWarning: FixedFormatter should only be used together with FixedLocator
#   df['year'].plot(kind='kde'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()

# %%
df[df['year'] < 2006]
# Out:
#      appointmentId  listingPrice       carName    make  model  variant  year  \
# 801     DLR1001215        130000  Maruti Swift  Maruti  Swift  VXI 1.3  2005
# 1477    DLR1001560        110000   Maruti Alto  Maruti   Alto       LX  2005
#
#      transmissionType   bodyType fuelType  ...  InfotainmentSystem  \
# 801            Manual  Hatchback   Petrol  ...                   0
# 1477           Manual  Hatchback   Petrol  ...                   0
#
#      LeatherSeats ParkingAssist PushButtonStart  RearAc SpecialRegNo  \
# 801             0             0               0       0            0
# 1477            0             0               0       0            0
#
#       Sunroof/Moonroof TopModel  Tpms  VentilatedSeats
# 801                  0        0     0                0
# 1477                 0        0     0                0
#
# [2 rows x 47 columns]

# %% [markdown]
# ##### ownership
#
# - most of the cars sold are 1st owners with some outliars where 7th owner cars are also sold : swift deisel

# %%
df['ownership'].describe()
# Out:
# count    7391.000000
# mean        1.352591
# std         0.654034
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         7.000000
# Name: ownership, dtype: float64

# %%
df['ownership'].plot(kind='hist', bins=20, edgecolor='black'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()
df['ownership'].plot(kind='kde'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()
# Out:
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\2501017599.py:1: UserWarning: FixedFormatter should only be used together with FixedLocator
#   df['ownership'].plot(kind='hist', bins=20, edgecolor='black'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\2501017599.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   df['ownership'].plot(kind='kde'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()

# %%
df[df['ownership'] > 6]
# Out:
#      appointmentId  listingPrice             carName    make        model  \
# 2847   11757248718        300000  Maruti Swift Dzire  Maruti  Swift Dzire
# 2921   15437446753        220000        Maruti Swift  Maruti        Swift
#
#      variant  year transmissionType   bodyType fuelType  ...  \
# 2847     VDI  2014           Manual      Sedan   Diesel  ...
# 2921     VDI  2012           Manual  Hatchback   Diesel  ...
#
#       InfotainmentSystem LeatherSeats ParkingAssist PushButtonStart  RearAc  \
# 2847                   0            0             0               0       0
# 2921                   0            0             0               0       0
#
#      SpecialRegNo  Sunroof/Moonroof TopModel  Tpms  VentilatedSeats
# 2847            0                 0        0     0                0
# 2921            0                 0        0     0                0
#
# [2 rows x 47 columns]

# %% [markdown]
# ##### odometer
#
# - most of the cars are driven less then 100000kms
# - Elantra being drive close to 9lakh kms

# %%
df['odometer'].describe()
# Out:
# count      7391.000000
# mean      65786.108781
# std       49210.647537
# min           1.000000
# 25%       33813.000000
# 50%       58739.000000
# 75%       84471.500000
# max      890000.000000
# Name: odometer, dtype: float64

# %%
df['odometer'].plot(kind='hist', bins=10, edgecolor='black'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()
df['odometer'].plot(kind='kde'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()
# Out:
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\3577361020.py:1: UserWarning: FixedFormatter should only be used together with FixedLocator
#   df['odometer'].plot(kind='hist', bins=10, edgecolor='black'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\3577361020.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   df['odometer'].plot(kind='kde'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()

# %%
df[df['odometer'] == 890000]
# Out:
#      appointmentId  listingPrice              carName     make        model  \
# 4176   12533044715        214000  Hyundai New Elantra  Hyundai  New Elantra
#
#                  variant  year transmissionType bodyType fuelType  ...  \
# 4176  1.6 SX (O) AT CRDI  2012        Automatic    Sedan   Diesel  ...
#
#       InfotainmentSystem LeatherSeats ParkingAssist PushButtonStart  RearAc  \
# 4176                   0            1             1               0       1
#
#      SpecialRegNo  Sunroof/Moonroof TopModel  Tpms  VentilatedSeats
# 4176            1                 0        0     0                1
#
# [1 rows x 47 columns]

# %% [markdown]
# ##### fitnessAge
#
# - Most of the cars have a fitness age of 15, indicating that the majority are likely considered in "good fitness" or "well-maintained" condition.

# %%
df['fitnessAge'].describe()
# Out:
# count    7391.000000
# mean       14.509945
# std         0.943823
# min        10.000000
# 25%        14.000000
# 50%        15.000000
# 75%        15.000000
# max        15.000000
# Name: fitnessAge, dtype: float64

# %% [markdown]
# #### Univariate Analysis on Categorical Columns
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### carName

# %%
df['carName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='carName'>

# %%
# car name doesnt seems to be a good column, we can remove this

# %% [markdown]
# ##### make
#
# - maruti, hyundai & tata among the highest sellers

# %%
df['make'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='make'>

# %%
df['make'].value_counts().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### model & variant

# %%
df['model'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='model'>

# %%
# need to check if model & variant are important in factors in car pricing

# %% [markdown]
# ##### transmissionType

# %%
df['transmissionType'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='transmissionType'>

# %%
df['transmissionType'].value_counts().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### bodyType

# %%
df['bodyType'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='bodyType'>

# %%
df['bodyType'].value_counts().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### fuelType

# %%
df['fuelType'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='fuelType'>

# %%
df['fuelType'].value_counts().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: ylabel='count'>

# %%
#registeredCity column already created
df.drop(columns=['cityRto'], inplace=True)

# %% [markdown]
# ##### color

# %%
df['color'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='color'>

# %% [markdown]
# ##### modelGroup

# %%
df['modelGroup'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='modelGroup'>

# %% [markdown]
# #### Bivariate
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### listingPrice vs year
#
# - Newer cars (higher year) tend to have higher prices, but the relationship is not very strong.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharex=True, sharey=True)

# Scatter plot
axes[0].scatter(df['year'], df['listingPrice'], s=10, alpha=0.3, color='red')
axes[0].set_title('Scatter Plot')

# 2D Histogram
axes[1].hexbin(df['year'], df['listingPrice'], gridsize=40, cmap='Blues')
axes[1].set_title('2D Histogram')

# 2D KDE
sns.kdeplot(data=df, x='year', y='listingPrice', fill=True, cmap='Greens', ax=axes[2])
axes[2].set_title('2D KDE')

# Common labels
for ax in axes:
    ax.set_xlabel('Year')
    ax.set_ylabel('Listing Price')
    ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# - corelation coeff
#
# ![image.png](attachment:image.png)

# %%
df['listingPrice'].corr(df['year'])
# Out:
# 0.3304575772944348

# %% [markdown]
# ##### listingprice vs ownership
#
# - ownership doesnt have any effect on price -- almost negligible in a practical sense.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharex=True, sharey=True)

# Scatter plot
axes[0].scatter(df['ownership'], df['listingPrice'], s=10, alpha=0.3, color='red')
axes[0].set_title('Scatter Plot')

# 2D Histogram
axes[1].hexbin(df['ownership'], df['listingPrice'], gridsize=40, cmap='Blues')
axes[1].set_title('2D Histogram')

# 2D KDE
sns.kdeplot(data=df, x='ownership', y='listingPrice', fill=True, cmap='Greens', ax=axes[2])
axes[2].set_title('2D KDE')

# Common labels
for ax in axes:
    ax.set_xlabel('ownership')
    ax.set_ylabel('Listing Price')
    ax.grid(True)

plt.tight_layout()
plt.show()


df['listingPrice'].corr(df['ownership'])
# Out:
# -0.14861629117627612

# %% [markdown]
# ##### listingprice vs odometer
#
# - surprisingly odometer also have negligible effect on price

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharex=True, sharey=True)

# Scatter plot
axes[0].scatter(df['odometer'], df['listingPrice'], s=10, alpha=0.3, color='red')
axes[0].set_title('Scatter Plot')

# 2D Histogram
axes[1].hexbin(df['odometer'], df['listingPrice'], gridsize=40, cmap='Blues')
axes[1].set_title('2D Histogram')

# 2D KDE
sns.kdeplot(data=df, x='odometer', y='listingPrice', fill=True, cmap='Greens', ax=axes[2])
axes[2].set_title('2D KDE')

# Common labels
for ax in axes:
    ax.set_xlabel('odometer')
    ax.set_ylabel('Listing Price')
    ax.grid(True)

plt.tight_layout()
plt.show()


df['listingPrice'].corr(df['odometer'])
# Out:
# -0.1309455730948185

# %% [markdown]
# ##### listingprice vs fitnessage
#
# - fitness age doesnt have any co-relation with price

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharex=True, sharey=True)

# Scatter plot
axes[0].scatter(df['fitnessAge'], df['listingPrice'], s=10, alpha=0.3, color='red')
axes[0].set_title('Scatter Plot')

# 2D Histogram
axes[1].hexbin(df['fitnessAge'], df['listingPrice'], gridsize=40, cmap='Blues')
axes[1].set_title('2D Histogram')

# 2D KDE
sns.kdeplot(data=df, x='fitnessAge', y='listingPrice', fill=True, cmap='Greens', ax=axes[2])
axes[2].set_title('2D KDE')

# Common labels
for ax in axes:
    ax.set_xlabel('fitnessAge')
    ax.set_ylabel('Listing Price')
    ax.grid(True)

plt.tight_layout()
plt.show()


df['listingPrice'].corr(df['fitnessAge'])
# Out:
# -0.1216103304907686

# %% [markdown]
# ##### creating new column: feature count

# %%
df['featureCount'] = df['features'].apply(len)

# %% [markdown]
# ##### price vs featureCount
#
# - oderate positive correlation b/w price & feature count, need to explore more

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharex=True, sharey=True)

# Scatter plot
axes[0].scatter(df['featureCount'], df['listingPrice'], s=10, alpha=0.3, color='red')
axes[0].set_title('Scatter Plot')

# 2D Histogram
axes[1].hexbin(df['featureCount'], df['listingPrice'], gridsize=40, cmap='Blues')
axes[1].set_title('2D Histogram')

# 2D KDE
sns.kdeplot(data=df, x='featureCount', y='listingPrice', fill=True, cmap='Greens', ax=axes[2])
axes[2].set_title('2D KDE')

# Common labels
for ax in axes:
    ax.set_xlabel('featureCount')
    ax.set_ylabel('Listing Price')
    ax.grid(True)

plt.tight_layout()
plt.show()


df['listingPrice'].corr(df['featureCount'])
# Out:
# 0.46140914817942813

# %% [markdown]
# ##### listingprice vs make

# %%
# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(18, 12))

# Barplot for 'make' vs 'listingPrice'
sns.barplot(x='make', y='listingPrice', data=df, ax=axes[0, 0], palette='Blues')
axes[0, 0].set_title('Barplot: Make vs Listing Price')
axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45, ha='right')

# Boxplot for 'make' vs 'listingPrice'
sns.boxplot(x='make', y='listingPrice', data=df, ax=axes[0, 1], palette='Blues')
axes[0, 1].set_title('Boxplot: Make vs Listing Price')
axes[0, 1].set_xticklabels(axes[0, 1].get_xticklabels(), rotation=45, ha='right')

# Violin plot for 'make' vs 'listingPrice'
sns.violinplot(x='make', y='listingPrice', data=df, ax=axes[1, 0], palette='Blues')
axes[1, 0].set_title('Violin Plot: Make vs Listing Price')
axes[1, 0].set_xticklabels(axes[1, 0].get_xticklabels(), rotation=45, ha='right')

# Adjust layout and show plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\476276468.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='make', y='listingPrice', data=df, ax=axes[0, 0], palette='Blues')
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\476276468.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45, ha='right')
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\476276468.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='make', y='listingPrice', data=df, ax=axes[0, 1], palette='Blues')
# ...

# %% [markdown]
# ##### price vs transmissionType

# %%
# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(18, 12))

# Barplot for 'transmissionType' vs 'listingPrice'
sns.barplot(x='transmissionType', y='listingPrice', data=df, ax=axes[0, 0], palette='Blues')
axes[0, 0].set_title('Barplot: transmissionType vs Listing Price')
axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45, ha='right')

# Boxplot for 'transmissionType' vs 'listingPrice'
sns.boxplot(x='transmissionType', y='listingPrice', data=df, ax=axes[0, 1], palette='Blues')
axes[0, 1].set_title('Boxplot: transmissionType vs Listing Price')
axes[0, 1].set_xticklabels(axes[0, 1].get_xticklabels(), rotation=45, ha='right')

# Violin plot for 'transmissionType' vs 'listingPrice'
sns.violinplot(x='transmissionType', y='listingPrice', data=df, ax=axes[1, 0], palette='Blues')
axes[1, 0].set_title('Violin Plot: transmissionType vs Listing Price')
axes[1, 0].set_xticklabels(axes[1, 0].get_xticklabels(), rotation=45, ha='right')

# Adjust layout and show plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\3025239233.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='transmissionType', y='listingPrice', data=df, ax=axes[0, 0], palette='Blues')
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\3025239233.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45, ha='right')
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\3025239233.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='transmissionType', y='listingPrice', data=df, ax=axes[0, 1], palette='Blues')
# ...

# %% [markdown]
# ##### price vs bodyType

# %%
# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(18, 12))

# Barplot for 'bodyType' vs 'listingPrice'
sns.barplot(x='bodyType', y='listingPrice', data=df, ax=axes[0, 0], palette='Blues')
axes[0, 0].set_title('Barplot: bodyType vs Listing Price')
axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45, ha='right')

# Boxplot for 'bodyType' vs 'listingPrice'
sns.boxplot(x='bodyType', y='listingPrice', data=df, ax=axes[0, 1], palette='Blues')
axes[0, 1].set_title('Boxplot: bodyType vs Listing Price')
axes[0, 1].set_xticklabels(axes[0, 1].get_xticklabels(), rotation=45, ha='right')

# Violin plot for 'bodyType' vs 'listingPrice'
sns.violinplot(x='bodyType', y='listingPrice', data=df, ax=axes[1, 0], palette='Blues')
axes[1, 0].set_title('Violin Plot: bodyType vs Listing Price')
axes[1, 0].set_xticklabels(axes[1, 0].get_xticklabels(), rotation=45, ha='right')

# Adjust layout and show plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\3415014488.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='bodyType', y='listingPrice', data=df, ax=axes[0, 0], palette='Blues')
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\3415014488.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45, ha='right')
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\3415014488.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='bodyType', y='listingPrice', data=df, ax=axes[0, 1], palette='Blues')
# ...

# %% [markdown]
# ##### price vs fuelType

# %%
# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(18, 12))

# Barplot for 'fuelType' vs 'listingPrice'
sns.barplot(x='fuelType', y='listingPrice', data=df, ax=axes[0, 0], palette='Blues')
axes[0, 0].set_title('Barplot: fuelType vs Listing Price')
axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45, ha='right')

# Boxplot for 'fuelType' vs 'listingPrice'
sns.boxplot(x='fuelType', y='listingPrice', data=df, ax=axes[0, 1], palette='Blues')
axes[0, 1].set_title('Boxplot: fuelType vs Listing Price')
axes[0, 1].set_xticklabels(axes[0, 1].get_xticklabels(), rotation=45, ha='right')

# Violin plot for 'fuelType' vs 'listingPrice'
sns.violinplot(x='fuelType', y='listingPrice', data=df, ax=axes[1, 0], palette='Blues')
axes[1, 0].set_title('Violin Plot: fuelType vs Listing Price')
axes[1, 0].set_xticklabels(axes[1, 0].get_xticklabels(), rotation=45, ha='right')

# Adjust layout and show plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\865655786.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='fuelType', y='listingPrice', data=df, ax=axes[0, 0], palette='Blues')
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\865655786.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45, ha='right')
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\865655786.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='fuelType', y='listingPrice', data=df, ax=axes[0, 1], palette='Blues')
# ...

# %% [markdown]
# ##### price vs color

# %%
# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(18, 12))

# Barplot for 'color' vs 'listingPrice'
sns.barplot(x='color', y='listingPrice', data=df, ax=axes[0, 0], palette='Blues')
axes[0, 0].set_title('Barplot: color vs Listing Price')
axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45, ha='right')

# Boxplot for 'color' vs 'listingPrice'
sns.boxplot(x='color', y='listingPrice', data=df, ax=axes[0, 1], palette='Blues')
axes[0, 1].set_title('Boxplot: color vs Listing Price')
axes[0, 1].set_xticklabels(axes[0, 1].get_xticklabels(), rotation=45, ha='right')

# Violin plot for 'color' vs 'listingPrice'
sns.violinplot(x='color', y='listingPrice', data=df, ax=axes[1, 0], palette='Blues')
axes[1, 0].set_title('Violin Plot: color vs Listing Price')
axes[1, 0].set_xticklabels(axes[1, 0].get_xticklabels(), rotation=45, ha='right')

# Adjust layout and show plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\806581257.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='color', y='listingPrice', data=df, ax=axes[0, 0], palette='Blues')
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\806581257.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45, ha='right')
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\806581257.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='color', y='listingPrice', data=df, ax=axes[0, 1], palette='Blues')
# ...

# %% [markdown]
# #### Multi Variate

# %%
df[numerical_columns].corrwith(df['listingPrice']).sort_values(ascending=False)
# Out:
# listingPrice                1.000000
# emiOriginalStartingValue    0.844049
# emiOriginalEndingValue      0.844049
# emiStartingValue            0.837311
# emiEndingValue              0.837311
# Tpms                        0.438516
# CruiseControl               0.408945
# LeatherSeats                0.402384
# Sunroof/Moonroof            0.391431
# PushButtonStart             0.343951
# year                        0.330458
# AlloyWheels                 0.311936
# InfotainmentSystem          0.309448
# RearAc                      0.298507
# GpsNavigation               0.282217
# 360DegreeCamera             0.279624
# VentilatedSeats             0.278734
# ParkingAssist               0.273635
# AppleCarplayAndroidAuto     0.272453
# Bluetooth                   0.240044
# tenure                      0.220507
# SpecialRegNo                0.115752
# TopModel                    0.002557
# fitnessAge                 -0.121610
# odometer                   -0.130946
# ...

# %%
df[['cashDownPayment', 'emiStartingValue',
       'emiEndingValue', 'roiMinDiscounted', 'roiMaxDiscounted',
       'roiMinOriginal', 'roiMaxOriginal', 'emiOriginalStartingValue',
       'emiOriginalEndingValue', 'tenure', 'displayText', 'notAvailableText']]
# Out:
#       cashDownPayment  emiStartingValue  emiEndingValue  roiMinDiscounted  \
# 0                   0             14956           14956                12
# 1                   0             22308           22308                11
# 2                   0             10674           10674                12
# 3                   0              6139            6139                12
# 4                   0              7566            7566                12
# ...               ...               ...             ...               ...
# 7386                0             13919           13919                12
# 7387                0             34718           34718                11
# 7388                0             23793           23793                11
# 7389                0             14459           14459                12
# 7390                0             26629           26629                11
#
#       roiMaxDiscounted  roiMinOriginal  roiMaxOriginal  \
# ...

# %% [markdown]
# #### Creating new columns -- feature engineering

# %% [markdown]
# ##### avg emi

# %%
df['avgEmi'] = df[['emiStartingValue', 'emiEndingValue']].mean(axis=1)

# %% [markdown]
# ##### emi spread

# %%
df['emiRange'] = df['emiEndingValue'] - df['emiStartingValue']

# %% [markdown]
# ##### intrest rate spread

# %%
df['roiRange'] = df['roiMaxOriginal'] - df['roiMinOriginal']

# %%
df.drop(columns=['appointmentId','carName','modelGroup','features', 'displayText', 'notAvailableText','tenure'], inplace=True)

# %%
df.columns
# Out:
# Index(['listingPrice', 'make', 'model', 'variant', 'year', 'transmissionType',
#        'bodyType', 'fuelType', 'ownership', 'registrationDate', 'color',
#        'odometer', 'fitnessAge', 'cashDownPayment', 'emiStartingValue',
#        'emiEndingValue', 'roiMinDiscounted', 'roiMaxDiscounted',
#        'roiMinOriginal', 'roiMaxOriginal', 'emiOriginalStartingValue',
#        'emiOriginalEndingValue', 'registeredCity', '360DegreeCamera',
#        'AlloyWheels', 'AppleCarplayAndroidAuto', 'Bluetooth', 'CruiseControl',
#        'GpsNavigation', 'InfotainmentSystem', 'LeatherSeats', 'ParkingAssist',
#        'PushButtonStart', 'RearAc', 'SpecialRegNo', 'Sunroof/Moonroof',
#        'TopModel', 'Tpms', 'VentilatedSeats', 'featureCount', 'avgEmi',
#        'emiRange', 'roiRange'],
#       dtype='object')

# %% [markdown]
# #### EDA on EMI columns

# %% [markdown]
# ##### univariate

# %%
df['avgEmi'].describe().apply(lambda x: f"{x:,.0f}")
# Out:
# count      7,391
# mean      15,414
# std       17,266
# min          782
# 25%        8,796
# 50%       12,023
# 75%       16,836
# max      476,377
# Name: avgEmi, dtype: object

# %%
df['avgEmi'].plot(kind='hist', bins=20, edgecolor='black'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()
df['avgEmi'].plot(kind='kde'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()
# Out:
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\2327109025.py:1: UserWarning: FixedFormatter should only be used together with FixedLocator
#   df['avgEmi'].plot(kind='hist', bins=20, edgecolor='black'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()
# C:\Users\iampr\AppData\Local\Temp\ipykernel_6964\2327109025.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   df['avgEmi'].plot(kind='kde'); plt.gca().set_xticklabels([f"{int(x):,}" for x in plt.gca().get_xticks()]); plt.show()

# %%
df.drop(columns=['emiRange'], inplace=True)

# %%
df.drop(columns=['roiRange'], inplace=True)

# %% [markdown]
# ##### bivariate

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharex=True, sharey=True)

# Scatter plot
axes[0].scatter(df['avgEmi'], df['listingPrice'], s=10, alpha=0.3, color='red')
axes[0].set_title('Scatter Plot')

# 2D Histogram
axes[1].hexbin(df['avgEmi'], df['listingPrice'], gridsize=40, cmap='Blues')
axes[1].set_title('2D Histogram')

# 2D KDE
sns.kdeplot(data=df, x='avgEmi', y='listingPrice', fill=True, cmap='Greens', ax=axes[2])
axes[2].set_title('2D KDE')

# Common labels
for ax in axes:
    ax.set_xlabel('avgEmi')
    ax.set_ylabel('Listing Price')
    ax.grid(True)

plt.tight_layout()
plt.show()


df['listingPrice'].corr(df['avgEmi'])
# Out:
# 0.8373108765549915

# %% [markdown]
# ##### Dropping registraiondate

# %%
#since year already have this info
df.drop(columns=['registrationDate'], inplace=True)

# %% [markdown]
# #### Conclusion after EDA
#
# 1. Important Columns on which price is depending:
#
#     - year
#     - feature count
#     - make
#     - transmission type
#     - bodytype
#     - fuel type
#     - color
#     - avgemi
#
# 2. Start with all columns and let `feature selection` or `model performance` guide.. Don't drop columns too early based only on intuition or EDA.
#
#     ![image.png](attachment:image.png)
#
# 3. Start with all columns, train baseline model, use feature selection and perform experiment

# %%
df.sample(3)
# Out:
#       listingPrice     make        model          variant  year  \
# 5424        506000   Maruti  New Wagon-R  LXI CNG (O) 1.0  2021
# 2305        270000  Hyundai          Eon            ERA +  2017
# 4159        200000   Maruti        Swift              VXI  2012
#
#      transmissionType   bodyType fuelType  ownership   color  ...  \
# 5424           Manual  Hatchback      CNG          1  Silver  ...
# 2305           Manual  Hatchback   Petrol          1   White  ...
# 4159           Manual  Hatchback   Petrol          2   White  ...
#
#       ParkingAssist  PushButtonStart  RearAc  SpecialRegNo  Sunroof/Moonroof  \
# 5424              1                0       0             0                 0
# 2305              0                0       0             0                 0
# 4159              0                0       0             0                 0
#
#       TopModel  Tpms  VentilatedSeats  featureCount  avgEmi
# 5424         0     0                0            17  9892.0
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# registeredCity              1222
# color                         48
# listingPrice                   0
# ParkingAssist                  0
# AlloyWheels                    0
# AppleCarplayAndroidAuto        0
# Bluetooth                      0
# CruiseControl                  0
# GpsNavigation                  0
# InfotainmentSystem             0
# LeatherSeats                   0
# PushButtonStart                0
# RearAc                         0
# SpecialRegNo                   0
# Sunroof/Moonroof               0
# TopModel                       0
# Tpms                           0
# VentilatedSeats                0
# featureCount                   0
# 360DegreeCamera                0
# emiOriginalEndingValue         0
# make                           0
# odometer                       0
# model                          0
# variant                        0
# year                           0
# transmissionType               0
# bodyType                       0
# ...

# %%
df.drop(columns=['registeredCity'], inplace=True)

# %% [markdown]
# ##### exporting data

# %%
df.to_excel("cars24_v3.xlsx", index=False)

# %% [markdown]
# ### Experiments

# %% [markdown]
# ##### 1. **Text Vectorization Techniques:**
# If you have text data, the common techniques include:
# - **None** (no text data or no text vectorization applied)
# - **Count Vectorizer**
# - **TF-IDF Vectorizer**
# - **Word2Vec** or **Pre-trained embeddings (e.g., GloVe)**
# - **Transformer-based embeddings** (e.g., BERT)
#
# **Total Options** = 5 (including "None" for cases where there is no text data)
#
# ##### 2. **Scaling Techniques:**
# There are several standard scaling techniques you can apply to numerical features:
# - **None** (no scaling applied)
# - **StandardScaler** (z-score normalization)
# - **MinMaxScaler** (scaling to [0, 1])
# - **RobustScaler** (scaling based on IQR, resistant to outliers)
#
# **Total Options** = 4
#
# ##### 3. **Feature Selection Techniques:**
# Feature selection can be done in several ways:
# - **None** (no feature selection applied)
# - **Filter-based** (e.g., ANOVA F-test, Mutual Information)
# - **Wrapper-based** (e.g., Recursive Feature Elimination)
# - **Embedded** (e.g., Lasso regularization, tree-based feature importance)
#
# **Total Options** = 4
#
# ##### 4. **Missing Value Imputation Techniques:**
# For handling missing values, the following techniques can be used:
# - **None** (no imputation applied)
# - **Mean Imputation** (for numerical features)
# - **Median Imputation** (for numerical features)
# - **Mode Imputation** (for categorical features)
# - **KNN Imputation** (for both numerical and categorical features)
# - **Iterative Imputation** (using models to predict missing values)
#
# **Total Options** = 6
#
# ##### 5. **Algorithm Options:**
# The following are common machine learning algorithms:
# - **Logistic Regression**
# - **Random Forest**
# - **XGBoost**
# - **KNN (K-Nearest Neighbors)**
# - **SVM (Support Vector Machine)**
#
# **Total Options** = 5
#
#
# ##### **Baseline Model:**
# A baseline model generally involves a simple model with minimal preprocessing. We can assume the following:
# - **Text Vectorization**: OHE
# - **Scaling**: None (no scaling)
# - **Feature Selection**: None (no feature selection)
# - **Imputation**: Mean (for numerical) and Mode (for categorical)
# - **Algorithm**: Logistic Regression (or a simple model)
#
# Thus, the **baseline model** adds 1 more combination.
#
#
# ##### **Total Number of Combinations:**
#
# Now, let's calculate the total number of combinations of the techniques (including the baseline model):
#
# \[
# \text{Total Combinations} = (\text{Text Vectorization Options}) \times (\text{Scaling Options}) \times (\text{Feature Selection Options}) \times (\text{Imputation Options}) \times (\text{Algorithm Options})
# \]
#
# \[
# \text{Total Combinations} = 5 \times 4 \times 4 \times 6 \times 5 = 2400
# \]
#
# **Including the baseline model**:
#
# \[
# \text{Total Combinations (with baseline)} = 2400 + 1 = 2401
# \]
#
# ##### **Summary:**
# - **Number of total combinations (including the baseline model)**: **2401**
